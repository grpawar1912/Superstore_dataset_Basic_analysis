# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("C:/Users/rfpaw/Downloads/P6-SuperStoreUS-2015 (1).xlsx",'Orders')

# %%
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      20847           High      0.01        2.84           0.93            3
# 1      20228  Not Specified      0.02      500.98          26.00            5
# 2      21776       Critical      0.06        9.48           7.29           11
# 3      24844         Medium      0.09       78.69          19.99           14
# 4      24846         Medium      0.08        3.28           2.31           14
# ...      ...            ...       ...         ...            ...          ...
# 1947   19842           High      0.01       10.90           7.46         3397
# 1948   19843           High      0.10        7.99           5.03         3397
# 1949   26208  Not Specified      0.08       11.97           5.81         3399
# 1950   24911         Medium      0.10        9.38           4.93         3400
# 1951   25914           High      0.10      105.98          13.99         3403
#
# ...

# %%
df.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
df.shape
# Out:
# (1952, 25)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Country', 'Region',
#        'State or Province', 'City', 'Postal Code', 'Order Date', 'Ship Date',
#        'Profit', 'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Country                         object
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# ...

# %%
df.tail(4)
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1948   19843           High      0.10        7.99           5.03         3397
# 1949   26208  Not Specified      0.08       11.97           5.81         3399
# 1950   24911         Medium      0.10        9.38           4.93         3400
# 1951   25914           High      0.10      105.98          13.99         3403
#
#       Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 1948    Andrea Shaw  Regular Air   Small Business       Technology  ...
# 1949    Marvin Reid  Regular Air   Small Business  Office Supplies  ...
# 1950  Florence Gold  Express Air   Small Business        Furniture  ...
# 1951  Tammy Buckley  Express Air         Consumer        Furniture  ...
#
#        Region State or Province         City  Postal Code Order Date  \
# 1948  Central          Illinois     Danville        61832 2015-03-11
# 1949  Central          Illinois  Des Plaines        60016 2015-03-29
# ...

# %%
df.iloc[1000:1200]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1000   25498           High      0.06       13.99           7.51         1778
# 1001   25499           High      0.06       15.04           1.97         1778
# 1002   19237           High      0.00       55.48          14.30         1781
# 1003   19419            Low      0.03        5.08           2.03         1781
# 1004   21283           High      0.03        3.28           3.97         1782
# ...      ...            ...       ...         ...            ...          ...
# 1195   21977           High      0.07      296.18          54.12         2157
# 1196   23775         Medium      0.08       30.98           8.74         2159
# 1197   23773         Medium      0.09      159.31          60.00         2162
# 1198   23774         Medium      0.06       55.99           5.00         2162
# 1199   22450  Not Specified      0.01        5.38           7.57         2164
#
# ...

# %%
df.loc[(df["Order Priority"]=="High")|(df["Order Priority"]=="Low")]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      20847           High      0.01        2.84           0.93            3
# 9      26267           High      0.04        2.98           1.58           16
# 10     26268           High      0.05      115.99           2.50           16
# 11     23890           High      0.05       26.48           6.93           18
# 13      5890           High      0.05       26.48           6.93           21
# ...      ...            ...       ...         ...            ...          ...
# 1940   22342            Low      0.01      125.99           8.99         3385
# 1946   20624            Low      0.00     1270.99          19.99         3397
# 1947   19842           High      0.01       10.90           7.46         3397
# 1948   19843           High      0.10        7.99           5.03         3397
# 1951   25914           High      0.10      105.98          13.99         3403
#
# ...

# %%
df.loc[(df["Region"]=="West")&(df["Discount"]>0.09)& (df["Customer Segment"]=="Corporate")]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 393     4616         Medium       0.1      175.99           8.99          698
# 394     1225            Low       0.1       40.48          19.99          698
# 470    20604            Low       0.1       50.98          22.24          851
# 520    21970            Low       0.1       15.98           4.00          920
# 730    19398            Low       0.1       34.23           5.02         1271
# 788    18702       Critical       0.1        8.17           1.69         1390
# 921    19252  Not Specified       0.1       95.99           4.90         1653
# 958     5670            Low       0.1       49.99          19.99         1723
# 1498   22438            Low       0.1       10.98           3.99         2647
# 1557   24523  Not Specified       0.1        5.18           5.74         2773
# 1912   23906            Low       0.1      120.98           9.07         3355
# ...

# %%
df.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     16
# Country                  0
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
df1=df.dropna()   #to delete null values from table

# %%
df1.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Country                 0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %%
df["Order Priority"].value_counts()
# Out:
# Order Priority
# Low              398
# Not Specified    396
# High             391
# Critical         390
# Medium           376
# Critical           1
# Name: count, dtype: int64

# %%
df["Order Priority"].value_counts(normalize=True)*100
# Out:
# Order Priority
# Low              20.389344
# Not Specified    20.286885
# High             20.030738
# Critical         19.979508
# Medium           19.262295
# Critical          0.051230
# Name: proportion, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1952 entries, 0 to 1951
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                1952 non-null   int64
#  1   Order Priority        1952 non-null   object
#  2   Discount              1952 non-null   float64
#  3   Unit Price            1952 non-null   float64
#  4   Shipping Cost         1952 non-null   float64
#  5   Customer ID           1952 non-null   int64
#  6   Customer Name         1952 non-null   object
#  7   Ship Mode             1952 non-null   object
#  8   Customer Segment      1952 non-null   object
#  9   Product Category      1952 non-null   object
#  10  Product Sub-Category  1952 non-null   object
#  11  Product Container     1952 non-null   object
#  12  Product Name          1952 non-null   object
#  13  Product Base Margin   1936 non-null   float64
#  14  Country               1952 non-null   object
# ...

# %%
df1.describe().T  # describe will show u statistcally summary
# Out:
#                        count                           mean  \
# Row ID                1936.0                   19917.548554
# Discount              1936.0                       0.048858
# Unit Price            1936.0                     108.034685
# Shipping Cost         1936.0                       12.78328
# Customer ID           1936.0                    1733.831095
# Product Base Margin   1936.0                       0.515186
# Postal Code           1936.0                   51545.004132
# Order Date              1936  2015-03-29 01:14:22.809917440
# Ship Date               1936  2015-03-30 23:53:18.347107328
# Profit                1936.0                     111.065806
# Quantity ordered new  1936.0                      12.965909
# Sales                 1936.0                     971.861968
# Order ID              1936.0                   82347.225207
#
#                                       min                  25%  \
# ...

# %%
df1.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Country                         object
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# ...

# %%
df1["Discount"]=df1["Discount"].astype("int")
# Out:
# C:\Users\rfpaw\AppData\Local\Temp\ipykernel_16608\3463309269.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Discount"]=df1["Discount"].astype("int")

# %%
df1.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                         int32
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Country                         object
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# ...

# %%
df1
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      20847           High         0        2.84           0.93            3
# 1      20228  Not Specified         0      500.98          26.00            5
# 2      21776       Critical         0        9.48           7.29           11
# 3      24844         Medium         0       78.69          19.99           14
# 4      24846         Medium         0        3.28           2.31           14
# ...      ...            ...       ...         ...            ...          ...
# 1947   19842           High         0       10.90           7.46         3397
# 1948   19843           High         0        7.99           5.03         3397
# 1949   26208  Not Specified         0       11.97           5.81         3399
# 1950   24911         Medium         0        9.38           4.93         3400
# 1951   25914           High         0      105.98          13.99         3403
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.pie(df1["Order Priority"].value_counts(normalize=True)*100,labels=df1["Order Priority"].unique())
# Out:
# ([<matplotlib.patches.Wedge at 0x20b0a705cd0>,
# ...
#  [Text(0.8805953678222177, 0.6592054294148777, 'High'),
#   Text(-0.3777127608186076, 1.033118129893569, 'Not Specified'),
#   Text(-1.0988647429716978, -0.0499627526638084, 'Critical'),
#   Text(-0.29617848384688555, -1.0593763758486217, 'Medium'),
#   Text(0.9004981279048805, -0.6317460895326584, 'Low'),
#   Text(1.0999985518350792, -0.001784925972928011, 'Critical ')])

# %%
plt.pie(df1["Order Priority"].value_counts(normalize=True)*100,labels=df1["Order Priority"].unique())
plt.show()

# %%
x=np.array([10,20,30,40])
y=np.array([50,60,70,80])

# %%
plt.subplot(3,3,1)
plt.pie(df1["Region"].value_counts(normalize=True)*100,labels=df1["Region"].unique())
plt.title("Region pie Graph ")
#plt.show()
plt.subplot(3,3,3)
plt.plot(x,y,"*")
plt.title("x vs y")
#plt.show()
plt.subplot(3,3,4)
plt.pie(df1["Customer Segment"].value_counts(normalize=True)*100,labels=df1["Customer Segment"].unique())
plt.title("Customer Segment graph")
#plt.show()
plt.subplot(3,3,5)
plt.plot(x,y,"r--")
plt.title("x vs y")
plt.subplot(3,3,7)
plt.plot(x,y,"g--*")
plt.title("x vs y")
plt.subplot(3,3,9)
plt.pie(df1["Ship Mode"].value_counts(normalize=True)*100,labels=df1["Ship Mode"].unique())
plt.title("Ship mode graph")
plt.show()

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 import seaborn as sns
# ----> 2 sns.barplot(x="Region",y="Sales",data=df1)
#
# NameError: name 'df1' is not defined

# %%
sns.barplot(x="Region",y="Sales",data=df1)
# Out:
# <Axes: xlabel='Region', ylabel='Sales'>

# %%
plt.figure(figsize=(18,7))
sns.barplot(x="Region",y="Unit Price",data=df1)
plt.show()

# %%
df1
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      20847           High         0        2.84           0.93            3
# 1      20228  Not Specified         0      500.98          26.00            5
# 2      21776       Critical         0        9.48           7.29           11
# 3      24844         Medium         0       78.69          19.99           14
# 4      24846         Medium         0        3.28           2.31           14
# ...      ...            ...       ...         ...            ...          ...
# 1947   19842           High         0       10.90           7.46         3397
# 1948   19843           High         0        7.99           5.03         3397
# 1949   26208  Not Specified         0       11.97           5.81         3399
# 1950   24911         Medium         0        9.38           4.93         3400
# 1951   25914           High         0      105.98          13.99         3403
#
# ...

# %%
df1.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Country', 'Region',
#        'State or Province', 'City', 'Postal Code', 'Order Date', 'Ship Date',
#        'Profit', 'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
sns.scatterplot(x="Unit Price",y="Shipping Cost",data=df1)  #both asis should be numerical
# Out:
# <Axes: xlabel='Unit Price', ylabel='Shipping Cost'>

# %%
df1.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                         int32
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Country                         object
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# ...

# %%
sns.lineplot(x="Ship Date",y="Sales",data=df1)
# Out:
# <Axes: xlabel='Ship Date', ylabel='Sales'>

# %%
df2=df1.head(100)

# %%
df2
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0    20847           High         0        2.84           0.93            3
# 1    20228  Not Specified         0      500.98          26.00            5
# 2    21776       Critical         0        9.48           7.29           11
# 3    24844         Medium         0       78.69          19.99           14
# 4    24846         Medium         0        3.28           2.31           14
# ..     ...            ...       ...         ...            ...          ...
# 95   19315            Low         0       43.22          16.71          169
# 96   19316            Low         0      574.74          24.49          169
# 97   19317            Low         0       10.14           2.27          169
# 98   19314       Critical         0        1.88           1.49          171
# 99    5361       Critical         0       49.99          19.99          181
#
# ...

# %%
sns.lineplot(x="Ship Date",y="Sales",data=df2)
# Out:
# <Axes: xlabel='Ship Date', ylabel='Sales'>

# %%
sns.lineplot(x="Order Date",y="Shipping Cost",data=df2)
# Out:
# <Axes: xlabel='Order Date', ylabel='Shipping Cost'>

# %%
sns.distplot(df2["Sales"])
# Out:
# C:\Users\rfpaw\AppData\Local\Temp\ipykernel_16608\3227226558.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2["Sales"])
# <Axes: xlabel='Sales', ylabel='Density'>

# %%
sns.pairplot(df1)
# Out:
# C:\Users\rfpaw\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(x="Order Priority",y="Sales",data=df2)
# Out:
# <Axes: xlabel='Order Priority', ylabel='Sales'>
